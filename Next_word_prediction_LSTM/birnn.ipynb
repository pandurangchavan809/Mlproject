# %% [markdown]
# ### These file is learning purpose and no connection with these project :- Created file here because topics are realted and i want all things at one place to revise

# %% [markdown]
# #### Example: Bidirectional RNN (BiLSTM) with IMDb Dataset

# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Bidirectional, Dense

# %%
# Load dataset (top 10,000 words)
vocab_size = 10000
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=vocab_size)

# Pad sequences to same length
max_len = 200
x_train = pad_sequences(x_train, maxlen=max_len, padding='post')
x_test = pad_sequences(x_test, maxlen=max_len, padding='post')

# %%
## Build the Bidirectional RNN Model
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=128, input_length=max_len),

    # Bidirectional LSTM layer
    Bidirectional(LSTM(64)),  # if you want better performance : Bidirectional(LSTM(64, return_sequences=True))
    # useful for stacking multiple RNN layers
    
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid')
])
# Out:
# c:\Users\PANDURANG\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
## compile the model
model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
## Train the model
history = model.fit(
    x_train, y_train,
    epochs=5,
    batch_size=64,
    validation_split=0.2
)
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 117s 358ms/step - accuracy: 0.7756 - loss: 0.4461 - val_accuracy: 0.8536 - val_loss: 0.4707
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 125s 399ms/step - accuracy: 0.9100 - loss: 0.2341 - val_accuracy: 0.8716 - val_loss: 0.3166
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 146s 467ms/step - accuracy: 0.9366 - loss: 0.1682 - val_accuracy: 0.8590 - val_loss: 0.3444
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 131s 418ms/step - accuracy: 0.9617 - loss: 0.1109 - val_accuracy: 0.8610 - val_loss: 0.4260
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 149s 475ms/step - accuracy: 0.9724 - loss: 0.0828 - val_accuracy: 0.8660 - val_loss: 0.4998

# %%
# Evaluate the model 
loss, accuracy = model.evaluate(x_test, y_test)
print("Test Accuracy:", accuracy)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 73s 93ms/step - accuracy: 0.8565 - loss: 0.5151
# Test Accuracy: 0.8565199971199036

# %% [markdown]
# ## Using GRU :

# %%
from tensorflow.keras.layers import GRU

model_gru = Sequential([
    Embedding(vocab_size, 128, input_length=max_len),
    Bidirectional(GRU(64, return_sequences=True)),
    Dense(1, activation='sigmoid')
])
# Out:
# c:\Users\PANDURANG\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
## use above code and train model save in model_gru

# %%
# evaluate both model and comapre
